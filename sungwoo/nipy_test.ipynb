# %%
import niwidgets

# %%
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK

# %%
# !jupyter nbextension enable --py --sys-prefix ipyvolume
# Out:
# Enabling notebook extension ipyvolume/extension...
#       - Validating: OK

# %%
# Let's try a simple parcellation map from a standard atlas
from niwidgets import NiftiWidget
from niwidgets import examplet1

test_widget = NiftiWidget(examplet1)
test_widget.nifti_plotter()
# Out:
# interactive(children=(IntSlider(value=45, continuous_update=False, description='x', max=90), IntSlider(value=5…

# %%
import nilearn.plotting as nip

test_widget.nifti_plotter(plotting_func=nip.plot_epi, 
                          display_mode=['ortho', 'x', 'y', 'z', 'yx', 'xz', 'yz'])
# Out:
# interactive(children=(Dropdown(description='display_mode', options=('ortho', 'x', 'y', 'z', 'yx', 'xz', 'yz'),…

# %%
my_test_data_widget = NiftiWidget('test_image.nii.gz')
my_test_data_widget.nifti_plotter(plotting_func=nip.plot_epi,
                                  display_mode=['ortho', 'x', 'y', 'z', 'yx', 'xz', 'yz'])
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-22-2b75dd866017> in <module>
# ----> 1 my_test_data_widget = NiftiWidget('test_image.nii.gz')
#       2 my_test_data_widget.nifti_plotter(plotting_func=nip.plot_epi,
#       3                                   display_mode=['ortho', 'x', 'y', 'z', 'yx', 'xz', 'yz'])
#
# ~/anaconda3/envs/tf3/lib/python3.6/site-packages/niwidgets/niwidget_volume.py in __init__(self, filename)
#      41             filename = str(filename)
#      42             if not os.path.isfile(filename):
# ---> 43                 raise OSError("File " + filename + " not found.")
#      44
#      45             # load data in advance
#
# OSError: File test_image.nii.gz not found.

# %%
my_test_data_widget = NiftiWidget('/home/cocoan-gpu1/Documents/beta_0001.nii')
my_test_data_widget.nifti_plotter(plotting_func=nip.plot_epi,
                                  display_mode=['ortho', 'x', 'y', 'z', 'yx', 'xz', 'yz'])
# Out:
# interactive(children=(Dropdown(description='display_mode', options=('ortho', 'x', 'y', 'z', 'yx', 'xz', 'yz'),…

# %%
from niwidgets import examplezmap
import nilearn.plotting as nip
test = NiftiWidget(examplezmap)
test.nifti_plotter(plotting_func=nip.plot_glass_brain, 
                   threshold=(0.0, 10.0, 0.01),
                   display_mode=['ortho','xz'])
# Out:
# interactive(children=(FloatSlider(value=5.0, description='threshold', max=10.0, step=0.01), Dropdown(descripti…

# %%
nip.plot_glass_brain('/home/cocoan-gpu1/Documents/beta_0001.nii', threshold=3)

# %%
import numpy as np
import pandas as pd

# %%
pd_data = pd.read_csv('/home/cocoan-gpu1/Documents/SEMIC_10sub_cef.csv')

# %%
pd_data = pd_data['Coeff']

# %%
np_coef = np.array(pd_data)

# %%
np_coef = np.reshape(np_coef,(79,95,79))

# %%
import nibabel as nib

# %%
img= nib.load('/home/cocoan-gpu1/Documents/beta_0001.nii')

# %%
type(img)
# Out:
# nibabel.nifti1.Nifti1Image

# %%
data= np_coef

# %%
affine = img.affine

# %%
new_image = nib.Nifti1Image(data, affine)

# %%
type(new_image)
# Out:
# nibabel.nifti1.Nifti1Image

# %%
nib.save(new_image, 'test_image.nii.gz')

# %%
test_image = nib.load('test_image.nii.gz')

# %%
from nilearn import image

# %%
nip.plot_glass_brain('/home/cocoan-gpu1/Documents/beta_0001.nii', threshold=4)

# %%
nip.plot_glass_brain(new_image)

# %%
nip.plot_stat_map('/home/cocoan-gpu1/Documents/beta_0001.nii',cut_coords=(10,50,50), threshold=2)

# %%
nip.plot_stat_map(new_image)

# %%
nip.plot_epi('/home/cocoan-gpu1/Documents/beta_0001.nii',cut_coords=(10,50,50),cmap='Greys')

# %%
nip.plot_epi(new_image,cut_coords=(10,50,50),cmap='Greys')

# %%
nip.plot_anat('/home/cocoan-gpu1/Documents/beta_0001.nii',cut_coords=(10,50,50))

# %%
nip.plot_anat(new_image,cut_coords=(10,50,50))

# %%
from nilearn import plotting, datasets

img = datasets.fetch_localizer_button_task()['tmap']
plotting.view_img(img, threshold=2, vmax=4, cut_coords=[-42,-16,52], title="Motor contrast")
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
#
# &lt;head&gt;
# &lt;/head&gt;
# &lt;body&gt;
#   &lt;div id=&quot;div_viewer&quot;&gt;
#     &lt;!-- this is the canvas that will feature the brain slices --&gt;
#     &lt;canvas id=&quot;3Dviewer&quot;&gt;
#     &lt;!-- load a hidden version of the sprite image that includes all (sagital) brain slices --&gt;
#     &lt;img id=&quot;spriteImg&quot; class=&quot;hidden&quot; src=&quot;...

# %%
plotting.view_img(new_image, vmax=4, cut_coords=[-42,-16,52], title="Coef")
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
#
# &lt;head&gt;
# &lt;/head&gt;
# &lt;body&gt;
#   &lt;div id=&quot;div_viewer&quot;&gt;
#     &lt;!-- this is the canvas that will feature the brain slices --&gt;
#     &lt;canvas id=&quot;3Dviewer&quot;&gt;
#     &lt;!-- load a hidden version of the sprite image that includes all (sagital) brain slices --&gt;
#     &lt;img id=&quot;spriteImg&quot; class=&quot;hidden&quot; src=&quot;...

# %%
img= nib.load('/home/cocoan-gpu1/Documents/beta_0001.nii')
plotting.view_img(img, threshold=2, vmax=4, cut_coords=[-42,-16,52], title="SEMIC")
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
#
# &lt;head&gt;
# &lt;/head&gt;
# &lt;body&gt;
#   &lt;div id=&quot;div_viewer&quot;&gt;
#     &lt;!-- this is the canvas that will feature the brain slices --&gt;
#     &lt;canvas id=&quot;3Dviewer&quot;&gt;
#     &lt;!-- load a hidden version of the sprite image that includes all (sagital) brain slices --&gt;
#     &lt;img id=&quot;spriteImg&quot; class=&quot;hidden&quot; src=&quot;...
