# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import nibabel as nib
import cv2
from mlxtend.preprocessing import one_hot
import timeit
from random import shuffle
from MPC_tools import *
from layers import *

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix


# %matplotlib inline

# %% [markdown]
# # Making files path list

# %%
base_dir = '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data'

# %%
dir_path_list = []
filenames_list = []

for dirpath, dirnames, filenames in os.walk(base_dir):
    if 'model' in dirpath:
        dir_path_list.append(dirpath)

        temp_filenames_list=[]
        for i in range(len(filenames)):
            if 'sub' and 'npy' in filenames[i]:
                temp_filenames_list.append(filenames[i])
        filenames_list.append(temp_filenames_list)
        
dir_path_list = np.array(dir_path_list)
filenames_list = np.array(filenames_list)
filenames_list = np.sort(filenames_list, axis=1)

full_path_list = []

for i in range(dir_path_list.shape[0]):
    temp_path_list=[]
    for j in range(len(filenames_list[i])):
        temp_path = os.path.join(dir_path_list[i], filenames_list[i][j])
        temp_path_list.append(temp_path)
    full_path_list.append(temp_path_list)

full_path_list = np.array(full_path_list)

# %%
dir_path_list
# Out:
# array(['/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL',
#        '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL'],
#       dtype='<U88')

# %%
filenames_list.shape
# Out:
# (2, 58)

# %%
full_path_list
# Out:
# array([['/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic001.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic002.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic003.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic004.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic005.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic006.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic007.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic008.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic009.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic010.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic011.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic012.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic013.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic014.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic015.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic016.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic018.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic019.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic020.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic021.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic022.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic023.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic024.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic025.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic026.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic027.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic028.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic029.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic030.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic031.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic032.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic033.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic034.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic035.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic036.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic037.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic038.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic039.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic040.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic041.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic042.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic043.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic044.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic045.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic046.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic047.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic048.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic049.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic050.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic051.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic052.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic053.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic054.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic055.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic056.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic057.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic058.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_FIR_SPM_SINGLE_TRIAL/model02_FIR_SPM_SINGLE_TRIAL_sub-semic059.npy'],
#        ['/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic001.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic002.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic003.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic004.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic005.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic006.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic007.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic008.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic009.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic010.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic011.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic012.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic013.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic014.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic015.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic016.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic018.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic019.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic020.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic021.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic022.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic023.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic024.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic025.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic026.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic027.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic028.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic029.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic030.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic031.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic032.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic033.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic034.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic035.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic036.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic037.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic038.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic039.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic040.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic041.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic042.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic043.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic044.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic045.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic046.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic047.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic048.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic049.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic050.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic051.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic052.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic053.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic054.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic055.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic056.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic057.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic058.npy',
#         '/home/cocoan-gpu1/D_drive/MPC/data/SEMIC/numpy_data/model02_Overall_FIR_SPM_SINGLE_TRIAL/model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic059.npy']],
#       dtype='<U142')

# %% [markdown]
# # Loading the data

# %%
def load_data(subjec_num, shuffle=False, nan_to_num=False, one_hot_y=False, flatten_X=False):
    import gc
    gc.collect()

    print("Loading {} data started ... ".format(filenames_list[0,subjec_num-1]))

    start = timeit.default_timer()

    X_stim = np.load(full_path_list[0,subjec_num-1])
    
    if nan_to_num:
        np.nan_to_num(X_stim)

    stop = timeit.default_timer()
    check_time = stop-start
    now = datetime.datetime.now()
    print("###  Duration Time  : {} minutes   {} seconds      ###".format(int(check_time)//60, int(check_time)%60))
    print("###  Excecuted Time : {}     ###".format(now))
    print('\n')

    print("Loading {} data started ... ".format(filenames_list[1,subjec_num-1]))

    start = timeit.default_timer()

    X_control = np.load(full_path_list[1,subjec_num-1])
    
    if nan_to_num:
        np.nan_to_num(X_control)
    
    stop = timeit.default_timer()
    check_time = stop-start
    now = datetime.datetime.now()
    print("###  Duration Time  : {} minutes   {} seconds      ###".format(int(check_time)//60, int(check_time)%60))
    print("###  Excecuted Time : {}     ###".format(now))
    print('\n')
    
    print("{} data shape is {}".format(filenames_list[0,subjec_num-1], X_stim.shape))
    print("{} data shape is {}".format(filenames_list[1,subjec_num-1], X_control.shape))
    print('\n')

    print("Concatenating is started.")
    print("Shuffle is {}".format(shuffle))
    print("NaN to number is {}".format(nan_to_num))
    print("Y One hot transform is {}".format(one_hot_y))
    print("flatten X is {}".format(flatten_X))
    print("\n")

    stim_index_list = np.arange(0,X_stim.shape[0])
    
    if shuffle:
        np.random.shuffle(stim_index_list)
    
    X = np.concatenate((X_stim[stim_index_list[:X_control.shape[0]],:,:,:], X_control), axis=0)
    
    if shuffle:
        index = np.arange(0,X.shape[0])
        np.random.shuffle(index)
        X = X[index,:,:,:]
    
    X = X[:,:,:,:,np.newaxis]
    
    if flatten_X:
        X = X.reshape((X.shape[0],-1))
    
    print("Concatenated data shape is : {}".format(X.shape))
    print("\n")

    
    Y_stim = np.ones(X_control.shape[0], dtype='i4')
    Y_control = np.zeros(X_control.shape[0], dtype='i4')
    Y = np.concatenate((Y_stim, Y_control), axis=0)
    
    if one_hot_y:
        from mlxtend.preprocessing import one_hot
        Y = one_hot(Y)
    
    if shuffle:
        Y = Y[index,:]
    
    print("Y shape is : {}".format(Y.shape))
    print("\n")

    del X_stim
    del X_control
    gc.collect()
    
    return X, Y

# %% [markdown]
# # Making tensorflow graph

# %%
def batch_norm(data, is_train, name=None):
    return tf.layers.batch_normalization(data, training=is_train, name=name)

# %%
num_classes = 2

# %%
x = tf.placeholder(tf.float32,shape=[None, 592895])
y_true = tf.placeholder(tf.float32,shape=[None,num_classes])
is_train = tf.placeholder(tf.bool)
hold_prob = tf.placeholder(tf.float32)

# %%
layer_1 = tf.layers.dense(x, 512)
layer_1_bath_norm = batch_norm(layer_1, is_train, name=None)
layer_1_relu = tf.nn.relu(layer_1_bath_norm)

# %%
layer_2 = tf.layers.dense(layer_1_bath_norm, 256)
layer_2_bath_norm = batch_norm(layer_2, is_train, name=None)
layer_2_relu = tf.nn.relu(layer_2_bath_norm)

# %%
16,16
# Out:
# (16, 16)

# %%
layer_3 = tf.layers.dense(layer_2_bath_norm, 128)
layer_3_bath_norm = batch_norm(layer_3, is_train, name=None)
layer_3_relu = tf.nn.relu(layer_3_bath_norm)

# %%
layer_4 = tf.layers.dense(layer_3_relu, 2)
layer_4 = tf.nn.sigmoid(layer_4)

# %%
y_pred = layer_4

# %%
cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y_true,logits=y_pred))
#cross_entropy = tf.reduce_mean(tf.losses.softmax_cross_entropy(y_true,y_pred))
#cross_entropy = tf.reduce_mean(tf.losses.sigmoid_cross_entropy(y_true,y_pred))
#mse = tf.losses.mean_squared_error(y_true, y_pred)
learning_rate = 1e-5
optimizer = tf.train.AdamOptimizer(learning_rate)

update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
with tf.control_dependencies(update_ops):
    train = optimizer.minimize(cross_entropy)
# Out:
# WARNING:tensorflow:From <ipython-input-17-10ce3dadea35>:1: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.

# %% [markdown]
# # data count
#
# total data = 4542
#
# train data = 3633
#
# validation data = 909

# %%
step_size = 4000

# %%
train_acc_list = []
train_entrop_list = []

test_acc_list = []
test_entrop_list = []

validation_acc_list = []
validataion_entrop_list = []

step_list = []

lowest_loss = None

X = []
Y = []

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    saver = tf.train.Saver()
    
    subject_num = 1
    start = timeit.default_timer()

    for i in range(step_size):
        
        #Loading training and validation data sets
        if i%36 == 0 and i < step_size-44:
            del X
            del Y
            
            X, Y = load_data(subject_num, shuffle=True, nan_to_num=True, one_hot_y=True, flatten_X=True)
            
            if subject_num<57:
                subject_num +=1   
            
            elif subject_num>=57:
                subject_num =1    

        #Load test data sets
        elif i == step_size-44:    
            validate_subjec_num = 58
            X, Y = load_data(validate_subjec_num, shuffle=True, nan_to_num=True, one_hot_y=True, flatten_X=True)

        matches = tf.equal(tf.argmax(y_pred,1),tf.argmax(y_true,1))
        acc = tf.reduce_mean(tf.cast(matches,tf.float32))
        
        #training model
        if i < step_size-44:
            j = i%44
            _, train_entropy, train_accuracy = sess.run([train, cross_entropy, acc], 
                                                        feed_dict={x: X[j*100:j*100+100], 
                                                                   y_true: Y[j*100:j*100+100], 
                                                                   hold_prob: 0.5, is_train:True})

            validation_entropy, validation_accuracy= sess.run([cross_entropy, acc],
                                                  feed_dict={x: X[4400:4500], 
                                                             y_true: Y[4400:4500], 
                                                             hold_prob:1.0, is_train:False})
            if i%10 == 0:
                print("* * * * * * * * * * * * *")
                print('Currently on step {}'.format(i))
                print('##Train Cross entropy is: {}'.format(train_entropy))
                print('##Train Accuracy is: {}'.format(train_accuracy))
                print('\n')
                print('##Validation Cross entropy is: {}'.format(validation_entropy))
                print('##Validation Accuracy is: {}'.format(validation_accuracy))

                print("* * * * * * * * * * * * *")
                print('\n')
                
            train_acc_list.append(train_accuracy)
            train_entrop_list.append(train_entropy)
            
            validation_acc_list.append(validation_accuracy)
            validataion_entrop_list.append(validation_entropy)
            
            step_list.append(i)

        #testing model
        elif i > step_size-44:
            j = i%44
            test_entropy, test_accuracy= sess.run([cross_entropy, acc],
                                                  feed_dict={x:X[j*100:j*100+100], 
                                                             y_true:Y[j*100:j*100+100], 
                                                             hold_prob:1.0, is_train:False})

            test_acc_list.append(test_accuracy)
            test_entrop_list.append(test_entropy)
            
            step_list.append(i)
            
            if i%1 == 0:
                print("* * * * * * * * * * * * *")
                print('Currently on step {}'.format(i))
                print('##Test Cross entropy is: {}'.format(test_entropy))
                print('##Test Accuracy is: {}'.format(test_accuracy))

                print("* * * * * * * * * * * * *")
                print('\n')
                

        if lowest_loss == None or lowest_loss > validation_entropy:
            lowest_loss = validation_entropy
            saver.save(sess, "./model/MPC_dnn_basic_SEMIC_binary_classification_ver4.ckpt")


train_acc_list = np.array(train_acc_list)
train_entrop_list = np.array(train_entrop_list)

test_entrop_list = np.array(test_entrop_list)
test_acc_list = np.array(test_acc_list)

validation_acc_list = np.array(validation_acc_list)
validataion_entrop_list = np.array(validataion_entrop_list)

step_list = np.array(step_list)

stop = timeit.default_timer()
check_time = stop-start
now = datetime.datetime.now()

print("!!!!Finished!!!!")
print("###  Duration Time  : {} minutes   {} seconds      ###".format(int(check_time)//60, int(check_time)%60))
print("###  Excecuted Time : {}     ###".format(now))
# Out:
# Loading model02_FIR_SPM_SINGLE_TRIAL_sub-semic001.npy data started ...
# ###  Duration Time  : 1 minutes   30 seconds      ###
# ###  Excecuted Time : 2019-04-25 11:47:27.835236     ###
#
#
# Loading model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic001.npy data started ...
# ###  Duration Time  : 0 minutes   39 seconds      ###
# ###  Excecuted Time : 2019-04-25 11:48:07.462362     ###
#
#
# model02_FIR_SPM_SINGLE_TRIAL_sub-semic001.npy data shape is (6051, 79, 95, 79)
# model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic001.npy data shape is (2271, 79, 95, 79)
#
#
# Concatenating is started.
# Shuffle is True
# NaN to number is True
# Y One hot transform is True
# flatten X is True
#
#
# Concatenated data shape is : (4542, 592895)
#
#
# Y shape is : (4542, 2)
#
#
# * * * * * * * * * * * * *
# Currently on step 0
# ##Train Cross entropy is: 0.6931471824645996
# ##Train Accuracy is: 0.41999998688697815
#
#
# ##Validation Cross entropy is: 0.693146824836731
# ##Validation Accuracy is: 0.5699999928474426
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 10
# ##Train Cross entropy is: 0.6931470632553101
# ##Train Accuracy is: 0.550000011920929
#
#
# ##Validation Cross entropy is: 0.6931468844413757
# ##Validation Accuracy is: 0.5699999928474426
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 20
# ##Train Cross entropy is: 0.6931481957435608
# ##Train Accuracy is: 0.3700000047683716
#
#
# ##Validation Cross entropy is: 0.6931467652320862
# ##Validation Accuracy is: 0.5699999928474426
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 30
# ##Train Cross entropy is: 0.6931474208831787
# ##Train Accuracy is: 0.4699999988079071
#
#
# ##Validation Cross entropy is: 0.6931465864181519
# ##Validation Accuracy is: 0.5699999928474426
# * * * * * * * * * * * * *
#
#
# Loading model02_FIR_SPM_SINGLE_TRIAL_sub-semic002.npy data started ...
# ###  Duration Time  : 1 minutes   30 seconds      ###
# ###  Excecuted Time : 2019-04-25 11:50:38.862292     ###
#
#
# Loading model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic002.npy data started ...
# ###  Duration Time  : 0 minutes   39 seconds      ###
# ###  Excecuted Time : 2019-04-25 11:51:18.468186     ###
#
#
# model02_FIR_SPM_SINGLE_TRIAL_sub-semic002.npy data shape is (6051, 79, 95, 79)
# model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic002.npy data shape is (2271, 79, 95, 79)
#
#
# Concatenating is started.
# Shuffle is True
# NaN to number is True
# Y One hot transform is True
# flatten X is True
#
#
# Concatenated data shape is : (4542, 592895)
#
#
# Y shape is : (4542, 2)
#
#
# * * * * * * * * * * * * *
# Currently on step 40
# ##Train Cross entropy is: 0.6931471824645996
# ##Train Accuracy is: 0.5
#
#
# ##Validation Cross entropy is: 0.6931474804878235
# ##Validation Accuracy is: 0.44999998807907104
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 50
# ##Train Cross entropy is: 0.6931471824645996
# ##Train Accuracy is: 0.47999998927116394
#
#
# ##Validation Cross entropy is: 0.6931470632553101
# ##Validation Accuracy is: 0.550000011920929
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 60
# ##Train Cross entropy is: 0.6931470632553101
# ##Train Accuracy is: 0.5099999904632568
#
#
# ##Validation Cross entropy is: 0.6931464672088623
# ##Validation Accuracy is: 0.550000011920929
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 70
# ##Train Cross entropy is: 0.6931476593017578
# ##Train Accuracy is: 0.47999998927116394
#
#
# ##Validation Cross entropy is: 0.693146288394928
# ##Validation Accuracy is: 0.550000011920929
# * * * * * * * * * * * * *
#
#
# Loading model02_FIR_SPM_SINGLE_TRIAL_sub-semic003.npy data started ...
# ###  Duration Time  : 1 minutes   30 seconds      ###
# ###  Excecuted Time : 2019-04-25 11:53:31.671648     ###
#
#
# Loading model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic003.npy data started ...
# ###  Duration Time  : 0 minutes   39 seconds      ###
# ###  Excecuted Time : 2019-04-25 11:54:11.395038     ###
#
#
# model02_FIR_SPM_SINGLE_TRIAL_sub-semic003.npy data shape is (6051, 79, 95, 79)
# model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic003.npy data shape is (2271, 79, 95, 79)
#
#
# Concatenating is started.
# Shuffle is True
# NaN to number is True
# Y One hot transform is True
# flatten X is True
#
#
# Concatenated data shape is : (4542, 592895)
#
#
# Y shape is : (4542, 2)
#
#
# * * * * * * * * * * * * *
# Currently on step 80
# ##Train Cross entropy is: 0.693147599697113
# ##Train Accuracy is: 0.46000000834465027
#
#
# ##Validation Cross entropy is: 0.693146824836731
# ##Validation Accuracy is: 0.550000011920929
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 90
# ##Train Cross entropy is: 0.6931471824645996
# ##Train Accuracy is: 0.49000000953674316
#
#
# ##Validation Cross entropy is: 0.6931470632553101
# ##Validation Accuracy is: 0.550000011920929
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 100
# ##Train Cross entropy is: 0.6931473016738892
# ##Train Accuracy is: 0.49000000953674316
#
#
# ##Validation Cross entropy is: 0.693146824836731
# ##Validation Accuracy is: 0.550000011920929
# * * * * * * * * * * * * *
#
#
# Loading model02_FIR_SPM_SINGLE_TRIAL_sub-semic004.npy data started ...
# ###  Duration Time  : 1 minutes   30 seconds      ###
# ###  Excecuted Time : 2019-04-25 11:56:07.443949     ###
#
#
# Loading model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic004.npy data started ...
# ###  Duration Time  : 0 minutes   39 seconds      ###
# ###  Excecuted Time : 2019-04-25 11:56:47.290310     ###
#
#
# model02_FIR_SPM_SINGLE_TRIAL_sub-semic004.npy data shape is (6051, 79, 95, 79)
# model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic004.npy data shape is (2271, 79, 95, 79)
#
#
# Concatenating is started.
# Shuffle is True
# NaN to number is True
# Y One hot transform is True
# flatten X is True
#
#
# Concatenated data shape is : (4542, 592895)
#
#
# Y shape is : (4542, 2)
#
#
# * * * * * * * * * * * * *
# Currently on step 110
# ##Train Cross entropy is: 0.6931474208831787
# ##Train Accuracy is: 0.4399999976158142
#
#
# ##Validation Cross entropy is: 0.6931469440460205
# ##Validation Accuracy is: 0.5600000023841858
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 120
# ##Train Cross entropy is: 0.6931473016738892
# ##Train Accuracy is: 0.4099999964237213
#
#
# ##Validation Cross entropy is: 0.6931471824645996
# ##Validation Accuracy is: 0.4399999976158142
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 130
# ##Train Cross entropy is: 0.6931471824645996
# ##Train Accuracy is: 0.550000011920929
#
#
# ##Validation Cross entropy is: 0.6931471824645996
# ##Validation Accuracy is: 0.4399999976158142
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 140
# ##Train Cross entropy is: 0.6931465864181519
# ##Train Accuracy is: 0.5600000023841858
#
#
# ##Validation Cross entropy is: 0.6931478381156921
# ##Validation Accuracy is: 0.4399999976158142
# * * * * * * * * * * * * *
#
#
# Loading model02_FIR_SPM_SINGLE_TRIAL_sub-semic005.npy data started ...
# ###  Duration Time  : 1 minutes   31 seconds      ###
# ###  Excecuted Time : 2019-04-25 11:58:44.361956     ###
#
#
# Loading model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic005.npy data started ...
# ###  Duration Time  : 0 minutes   39 seconds      ###
# ###  Excecuted Time : 2019-04-25 11:59:24.197082     ###
#
#
# model02_FIR_SPM_SINGLE_TRIAL_sub-semic005.npy data shape is (6051, 79, 95, 79)
# model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic005.npy data shape is (2271, 79, 95, 79)
#
#
# Concatenating is started.
# Shuffle is True
# NaN to number is True
# Y One hot transform is True
# flatten X is True
#
#
# Concatenated data shape is : (4542, 592895)
#
#
# Y shape is : (4542, 2)
#
#
# * * * * * * * * * * * * *
# Currently on step 150
# ##Train Cross entropy is: 0.6931450366973877
# ##Train Accuracy is: 0.6100000143051147
#
#
# ##Validation Cross entropy is: 0.6931471824645996
# ##Validation Accuracy is: 0.5
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 160
# ##Train Cross entropy is: 0.6931469440460205
# ##Train Accuracy is: 0.5099999904632568
#
#
# ##Validation Cross entropy is: 0.6931471824645996
# ##Validation Accuracy is: 0.5
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 170
# ##Train Cross entropy is: 0.6931446194648743
# ##Train Accuracy is: 0.5899999737739563
#
#
# ##Validation Cross entropy is: 0.6931471824645996
# ##Validation Accuracy is: 0.5
# * * * * * * * * * * * * *
# Loading model02_FIR_SPM_SINGLE_TRIAL_sub-semic006.npy data started ...
# ###  Duration Time  : 1 minutes   31 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:01:21.183861     ###
#
#
# Loading model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic006.npy data started ...
# ###  Duration Time  : 0 minutes   39 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:02:01.075471     ###
#
#
# model02_FIR_SPM_SINGLE_TRIAL_sub-semic006.npy data shape is (6051, 79, 95, 79)
# model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic006.npy data shape is (2271, 79, 95, 79)
#
#
# Concatenating is started.
# Shuffle is True
# NaN to number is True
# Y One hot transform is True
# flatten X is True
#
#
# Concatenated data shape is : (4542, 592895)
#
#
# Y shape is : (4542, 2)
#
#
# * * * * * * * * * * * * *
# Currently on step 180
# ##Train Cross entropy is: 0.693146824836731
# ##Train Accuracy is: 0.5099999904632568
#
#
# ##Validation Cross entropy is: 0.6931505799293518
# ##Validation Accuracy is: 0.4000000059604645
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 190
# ##Train Cross entropy is: 0.693144679069519
# ##Train Accuracy is: 0.5799999833106995
#
#
# ##Validation Cross entropy is: 0.6931505799293518
# ##Validation Accuracy is: 0.4000000059604645
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 200
# ##Train Cross entropy is: 0.6931462287902832
# ##Train Accuracy is: 0.5299999713897705
#
#
# ##Validation Cross entropy is: 0.6931506395339966
# ##Validation Accuracy is: 0.4000000059604645
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 210
# ##Train Cross entropy is: 0.6931478381156921
# ##Train Accuracy is: 0.47999998927116394
#
#
# ##Validation Cross entropy is: 0.6931501626968384
# ##Validation Accuracy is: 0.4000000059604645
# * * * * * * * * * * * * *
#
#
# Loading model02_FIR_SPM_SINGLE_TRIAL_sub-semic007.npy data started ...
# ###  Duration Time  : 1 minutes   31 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:03:58.395006     ###
#
#
# Loading model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic007.npy data started ...
# ###  Duration Time  : 0 minutes   39 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:04:38.268223     ###
#
#
# model02_FIR_SPM_SINGLE_TRIAL_sub-semic007.npy data shape is (6051, 79, 95, 79)
# model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic007.npy data shape is (2271, 79, 95, 79)
#
#
# Concatenating is started.
# Shuffle is True
# NaN to number is True
# Y One hot transform is True
# flatten X is True
#
#
# Concatenated data shape is : (4542, 592895)
#
#
# Y shape is : (4542, 2)
#
#
# * * * * * * * * * * * * *
# Currently on step 220
# ##Train Cross entropy is: 0.6931498050689697
# ##Train Accuracy is: 0.41999998688697815
#
#
# ##Validation Cross entropy is: 0.6931471824645996
# ##Validation Accuracy is: 0.5
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 230
# ##Train Cross entropy is: 0.6931474804878235
# ##Train Accuracy is: 0.49000000953674316
#
#
# ##Validation Cross entropy is: 0.6931471824645996
# ##Validation Accuracy is: 0.5
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 240
# ##Train Cross entropy is: 0.6931464672088623
# ##Train Accuracy is: 0.5199999809265137
#
#
# ##Validation Cross entropy is: 0.6931471824645996
# ##Validation Accuracy is: 0.5
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 250
# ##Train Cross entropy is: 0.6931463479995728
# ##Train Accuracy is: 0.5299999713897705
#
#
# ##Validation Cross entropy is: 0.6931471228599548
# ##Validation Accuracy is: 0.5
# * * * * * * * * * * * * *
#
#
# Loading model02_FIR_SPM_SINGLE_TRIAL_sub-semic008.npy data started ...
# ###  Duration Time  : 1 minutes   31 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:06:35.730478     ###
#
#
# Loading model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic008.npy data started ...
# ###  Duration Time  : 0 minutes   39 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:07:15.634847     ###
#
#
# model02_FIR_SPM_SINGLE_TRIAL_sub-semic008.npy data shape is (6051, 79, 95, 79)
# model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic008.npy data shape is (2271, 79, 95, 79)
#
#
# Concatenating is started.
# Shuffle is True
# NaN to number is True
# Y One hot transform is True
# flatten X is True
#
#
# Concatenated data shape is : (4542, 592895)
#
#
# Y shape is : (4542, 2)
#
#
# * * * * * * * * * * * * *
# Currently on step 260
# ##Train Cross entropy is: 0.6931474208831787
# ##Train Accuracy is: 0.49000000953674316
#
#
# ##Validation Cross entropy is: 0.6931501626968384
# ##Validation Accuracy is: 0.38999998569488525
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 270
# ##Train Cross entropy is: 0.6931478381156921
# ##Train Accuracy is: 0.47999998927116394
#
#
# ##Validation Cross entropy is: 0.6931514143943787
# ##Validation Accuracy is: 0.38999998569488525
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 280
# ##Train Cross entropy is: 0.6931471824645996
# ##Train Accuracy is: 0.5
#
#
# ##Validation Cross entropy is: 0.6931523680686951
# ##Validation Accuracy is: 0.38999998569488525
# * * * * * * * * * * * * *
#
#
# Loading model02_FIR_SPM_SINGLE_TRIAL_sub-semic009.npy data started ...
# ###  Duration Time  : 1 minutes   32 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:09:13.562993     ###
#
#
# Loading model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic009.npy data started ...
# ###  Duration Time  : 0 minutes   40 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:09:53.694554     ###
#
#
# model02_FIR_SPM_SINGLE_TRIAL_sub-semic009.npy data shape is (6051, 79, 95, 79)
# model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic009.npy data shape is (2271, 79, 95, 79)
#
#
# Concatenating is started.
# Shuffle is True
# NaN to number is True
# Y One hot transform is True
# flatten X is True
#
#
# Concatenated data shape is : (4542, 592895)
#
#
# Y shape is : (4542, 2)
#
#
# * * * * * * * * * * * * *
# Currently on step 290
# ##Train Cross entropy is: 0.6931465268135071
# ##Train Accuracy is: 0.5199999809265137
#
#
# ##Validation Cross entropy is: 0.6931495070457458
# ##Validation Accuracy is: 0.4300000071525574
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 300
# ##Train Cross entropy is: 0.6931455135345459
# ##Train Accuracy is: 0.5600000023841858
#
#
# ##Validation Cross entropy is: 0.693149209022522
# ##Validation Accuracy is: 0.4300000071525574
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 310
# ##Train Cross entropy is: 0.6931464672088623
# ##Train Accuracy is: 0.5199999809265137
#
#
# ##Validation Cross entropy is: 0.6931499242782593
# ##Validation Accuracy is: 0.4300000071525574
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 320
# ##Train Cross entropy is: 0.6931452751159668
# ##Train Accuracy is: 0.550000011920929
#
#
# ##Validation Cross entropy is: 0.6931499242782593
# ##Validation Accuracy is: 0.4300000071525574
# * * * * * * * * * * * * *
#
#
# Loading model02_FIR_SPM_SINGLE_TRIAL_sub-semic010.npy data started ...
# ###  Duration Time  : 1 minutes   32 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:11:52.114203     ###
#
#
# Loading model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic010.npy data started ...
# ###  Duration Time  : 0 minutes   40 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:12:32.225012     ###
#
#
# model02_FIR_SPM_SINGLE_TRIAL_sub-semic010.npy data shape is (6051, 79, 95, 79)
# model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic010.npy data shape is (2271, 79, 95, 79)
#
#
# Concatenating is started.
# Shuffle is True
# NaN to number is True
# Y One hot transform is True
# flatten X is True
#
#
# Concatenated data shape is : (4542, 592895)
#
#
# Y shape is : (4542, 2)
#
#
# * * * * * * * * * * * * *
# Currently on step 330
# ##Train Cross entropy is: 0.6931524872779846
# ##Train Accuracy is: 0.36000001430511475
#
#
# ##Validation Cross entropy is: 0.6931482553482056
# ##Validation Accuracy is: 0.4699999988079071
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 340
# ##Train Cross entropy is: 0.693148672580719
# ##Train Accuracy is: 0.4300000071525574
#
#
# ##Validation Cross entropy is: 0.6931477189064026
# ##Validation Accuracy is: 0.4699999988079071
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 350
# ##Train Cross entropy is: 0.693146824836731
# ##Train Accuracy is: 0.5299999713897705
#
#
# ##Validation Cross entropy is: 0.693147599697113
# ##Validation Accuracy is: 0.4699999988079071
# * * * * * * * * * * * * *
# Loading model02_FIR_SPM_SINGLE_TRIAL_sub-semic011.npy data started ...
# ###  Duration Time  : 1 minutes   32 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:14:30.845313     ###
#
#
# Loading model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic011.npy data started ...
# ###  Duration Time  : 0 minutes   40 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:15:10.999256     ###
#
#
# model02_FIR_SPM_SINGLE_TRIAL_sub-semic011.npy data shape is (6051, 79, 95, 79)
# model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic011.npy data shape is (2271, 79, 95, 79)
#
#
# Concatenating is started.
# Shuffle is True
# NaN to number is True
# Y One hot transform is True
# flatten X is True
#
#
# Concatenated data shape is : (4542, 592895)
#
#
# Y shape is : (4542, 2)
#
#
# * * * * * * * * * * * * *
# Currently on step 360
# ##Train Cross entropy is: 0.6931473612785339
# ##Train Accuracy is: 0.49000000953674316
#
#
# ##Validation Cross entropy is: 0.6931470632553101
# ##Validation Accuracy is: 0.5099999904632568
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 370
# ##Train Cross entropy is: 0.6931471228599548
# ##Train Accuracy is: 0.5
#
#
# ##Validation Cross entropy is: 0.6931470632553101
# ##Validation Accuracy is: 0.5099999904632568
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 380
# ##Train Cross entropy is: 0.6931473612785339
# ##Train Accuracy is: 0.44999998807907104
#
#
# ##Validation Cross entropy is: 0.6931471824645996
# ##Validation Accuracy is: 0.5099999904632568
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 390
# ##Train Cross entropy is: 0.6931470632553101
# ##Train Accuracy is: 0.5199999809265137
#
#
# ##Validation Cross entropy is: 0.6931473612785339
# ##Validation Accuracy is: 0.49000000953674316
# * * * * * * * * * * * * *
#
#
# Loading model02_FIR_SPM_SINGLE_TRIAL_sub-semic012.npy data started ...
# ###  Duration Time  : 1 minutes   32 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:17:09.916963     ###
#
#
# Loading model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic012.npy data started ...
# ###  Duration Time  : 0 minutes   40 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:17:50.084489     ###
#
#
# model02_FIR_SPM_SINGLE_TRIAL_sub-semic012.npy data shape is (6051, 79, 95, 79)
# model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic012.npy data shape is (2271, 79, 95, 79)
#
#
# Concatenating is started.
# Shuffle is True
# NaN to number is True
# Y One hot transform is True
# flatten X is True
#
#
# Concatenated data shape is : (4542, 592895)
#
#
# Y shape is : (4542, 2)
#
#
# * * * * * * * * * * * * *
# Currently on step 400
# ##Train Cross entropy is: 0.6931468844413757
# ##Train Accuracy is: 0.5199999809265137
#
#
# ##Validation Cross entropy is: 0.6931476593017578
# ##Validation Accuracy is: 0.44999998807907104
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 410
# ##Train Cross entropy is: 0.6931478977203369
# ##Train Accuracy is: 0.44999998807907104
#
#
# ##Validation Cross entropy is: 0.6931478977203369
# ##Validation Accuracy is: 0.44999998807907104
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 420
# ##Train Cross entropy is: 0.6931468844413757
# ##Train Accuracy is: 0.5199999809265137
#
#
# ##Validation Cross entropy is: 0.6931478977203369
# ##Validation Accuracy is: 0.44999998807907104
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 430
# ##Train Cross entropy is: 0.6931464672088623
# ##Train Accuracy is: 0.5400000214576721
#
#
# ##Validation Cross entropy is: 0.693148136138916
# ##Validation Accuracy is: 0.44999998807907104
# * * * * * * * * * * * * *
#
#
# Loading model02_FIR_SPM_SINGLE_TRIAL_sub-semic013.npy data started ...
# ###  Duration Time  : 1 minutes   32 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:19:49.310031     ###
#
#
# Loading model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic013.npy data started ...
# ###  Duration Time  : 0 minutes   40 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:20:29.822300     ###
#
#
# model02_FIR_SPM_SINGLE_TRIAL_sub-semic013.npy data shape is (6051, 79, 95, 79)
# model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic013.npy data shape is (2271, 79, 95, 79)
#
#
# Concatenating is started.
# Shuffle is True
# NaN to number is True
# Y One hot transform is True
# flatten X is True
#
#
# Concatenated data shape is : (4542, 592895)
#
#
# Y shape is : (4542, 2)
#
#
# * * * * * * * * * * * * *
# Currently on step 440
# ##Train Cross entropy is: 0.693147599697113
# ##Train Accuracy is: 0.46000000834465027
#
#
# ##Validation Cross entropy is: 0.6931470632553101
# ##Validation Accuracy is: 0.5199999809265137
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 450
# ##Train Cross entropy is: 0.6931473016738892
# ##Train Accuracy is: 0.46000000834465027
#
#
# ##Validation Cross entropy is: 0.6931471824645996
# ##Validation Accuracy is: 0.47999998927116394
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 460
# ##Train Cross entropy is: 0.6931473016738892
# ##Train Accuracy is: 0.4300000071525574
#
#
# ##Validation Cross entropy is: 0.6931471228599548
# ##Validation Accuracy is: 0.5199999809265137
# * * * * * * * * * * * * *
#
#
# Loading model02_FIR_SPM_SINGLE_TRIAL_sub-semic014.npy data started ...
# ###  Duration Time  : 1 minutes   32 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:22:29.314386     ###
#
#
# Loading model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic014.npy data started ...
# ###  Duration Time  : 0 minutes   40 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:23:09.831821     ###
#
#
# model02_FIR_SPM_SINGLE_TRIAL_sub-semic014.npy data shape is (6051, 79, 95, 79)
# model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic014.npy data shape is (2271, 79, 95, 79)
#
#
# Concatenating is started.
# Shuffle is True
# NaN to number is True
# Y One hot transform is True
# flatten X is True
#
#
# Concatenated data shape is : (4542, 592895)
#
#
# Y shape is : (4542, 2)
#
#
# * * * * * * * * * * * * *
# Currently on step 470
# ##Train Cross entropy is: 0.6931474804878235
# ##Train Accuracy is: 0.4399999976158142
#
#
# ##Validation Cross entropy is: 0.6931471228599548
# ##Validation Accuracy is: 0.5199999809265137
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 480
# ##Train Cross entropy is: 0.693146824836731
# ##Train Accuracy is: 0.5299999713897705
#
#
# ##Validation Cross entropy is: 0.6931474208831787
# ##Validation Accuracy is: 0.47999998927116394
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 490
# ##Train Cross entropy is: 0.6931469440460205
# ##Train Accuracy is: 0.5400000214576721
#
#
# ##Validation Cross entropy is: 0.6931471824645996
# ##Validation Accuracy is: 0.47999998927116394
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 500
# ##Train Cross entropy is: 0.6931473016738892
# ##Train Accuracy is: 0.4699999988079071
#
#
# ##Validation Cross entropy is: 0.6931471824645996
# ##Validation Accuracy is: 0.47999998927116394
# * * * * * * * * * * * * *
#
#
# Loading model02_FIR_SPM_SINGLE_TRIAL_sub-semic015.npy data started ...
# ###  Duration Time  : 1 minutes   32 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:25:09.872851     ###
#
#
# Loading model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic015.npy data started ...
# ###  Duration Time  : 0 minutes   40 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:25:50.331431     ###
#
#
# model02_FIR_SPM_SINGLE_TRIAL_sub-semic015.npy data shape is (6051, 79, 95, 79)
# model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic015.npy data shape is (2271, 79, 95, 79)
#
#
# Concatenating is started.
# Shuffle is True
# NaN to number is True
# Y One hot transform is True
# flatten X is True
#
#
# Concatenated data shape is : (4542, 592895)
#
#
# Y shape is : (4542, 2)
#
#
# * * * * * * * * * * * * *
# Currently on step 510
# ##Train Cross entropy is: 0.6931469440460205
# ##Train Accuracy is: 0.5299999713897705
#
#
# ##Validation Cross entropy is: 0.6931468844413757
# ##Validation Accuracy is: 0.550000011920929
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 520
# ##Train Cross entropy is: 0.6931471228599548
# ##Train Accuracy is: 0.49000000953674316
#
#
# ##Validation Cross entropy is: 0.6931470632553101
# ##Validation Accuracy is: 0.550000011920929
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 530
# ##Train Cross entropy is: 0.6931473612785339
# ##Train Accuracy is: 0.4399999976158142
#
#
# ##Validation Cross entropy is: 0.6931470632553101
# ##Validation Accuracy is: 0.550000011920929
# * * * * * * * * * * * * *
# Loading model02_FIR_SPM_SINGLE_TRIAL_sub-semic016.npy data started ...
# ###  Duration Time  : 1 minutes   33 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:27:50.886377     ###
#
#
# Loading model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic016.npy data started ...
# ###  Duration Time  : 0 minutes   40 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:28:31.431245     ###
#
#
# model02_FIR_SPM_SINGLE_TRIAL_sub-semic016.npy data shape is (6051, 79, 95, 79)
# model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic016.npy data shape is (2271, 79, 95, 79)
#
#
# Concatenating is started.
# Shuffle is True
# NaN to number is True
# Y One hot transform is True
# flatten X is True
#
#
# Concatenated data shape is : (4542, 592895)
#
#
# Y shape is : (4542, 2)
#
#
# * * * * * * * * * * * * *
# Currently on step 540
# ##Train Cross entropy is: 0.6931468844413757
# ##Train Accuracy is: 0.5299999713897705
#
#
# ##Validation Cross entropy is: 0.6931471824645996
# ##Validation Accuracy is: 0.5
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 550
# ##Train Cross entropy is: 0.6931474208831787
# ##Train Accuracy is: 0.44999998807907104
#
#
# ##Validation Cross entropy is: 0.6931471824645996
# ##Validation Accuracy is: 0.5
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 560
# ##Train Cross entropy is: 0.6931478977203369
# ##Train Accuracy is: 0.41999998688697815
#
#
# ##Validation Cross entropy is: 0.6931471824645996
# ##Validation Accuracy is: 0.5
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 570
# ##Train Cross entropy is: 0.693146824836731
# ##Train Accuracy is: 0.5299999713897705
#
#
# ##Validation Cross entropy is: 0.6931471824645996
# ##Validation Accuracy is: 0.5
# * * * * * * * * * * * * *
#
#
# Loading model02_FIR_SPM_SINGLE_TRIAL_sub-semic018.npy data started ...
# ###  Duration Time  : 1 minutes   33 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:30:32.677385     ###
#
#
# Loading model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic018.npy data started ...
# ###  Duration Time  : 0 minutes   40 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:31:13.352778     ###
#
#
# model02_FIR_SPM_SINGLE_TRIAL_sub-semic018.npy data shape is (6051, 79, 95, 79)
# model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic018.npy data shape is (2271, 79, 95, 79)
#
#
# Concatenating is started.
# Shuffle is True
# NaN to number is True
# Y One hot transform is True
# flatten X is True
#
#
# Concatenated data shape is : (4542, 592895)
#
#
# Y shape is : (4542, 2)
#
#
# * * * * * * * * * * * * *
# Currently on step 580
# ##Train Cross entropy is: 0.6931469440460205
# ##Train Accuracy is: 0.5799999833106995
#
#
# ##Validation Cross entropy is: 0.6931473612785339
# ##Validation Accuracy is: 0.44999998807907104
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 590
# ##Train Cross entropy is: 0.6931471228599548
# ##Train Accuracy is: 0.49000000953674316
#
#
# ##Validation Cross entropy is: 0.6931473612785339
# ##Validation Accuracy is: 0.44999998807907104
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 600
# ##Train Cross entropy is: 0.693146824836731
# ##Train Accuracy is: 0.5299999713897705
#
#
# ##Validation Cross entropy is: 0.6931477189064026
# ##Validation Accuracy is: 0.44999998807907104
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 610
# ##Train Cross entropy is: 0.6931473612785339
# ##Train Accuracy is: 0.47999998927116394
#
#
# ##Validation Cross entropy is: 0.6931473612785339
# ##Validation Accuracy is: 0.44999998807907104
# * * * * * * * * * * * * *
#
#
# Loading model02_FIR_SPM_SINGLE_TRIAL_sub-semic019.npy data started ...
# ###  Duration Time  : 1 minutes   33 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:33:14.992889     ###
#
#
# Loading model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic019.npy data started ...
# ###  Duration Time  : 0 minutes   40 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:33:55.804900     ###
#
#
# model02_FIR_SPM_SINGLE_TRIAL_sub-semic019.npy data shape is (6051, 79, 95, 79)
# model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic019.npy data shape is (2271, 79, 95, 79)
#
#
# Concatenating is started.
# Shuffle is True
# NaN to number is True
# Y One hot transform is True
# flatten X is True
#
#
# Concatenated data shape is : (4542, 592895)
#
#
# Y shape is : (4542, 2)
#
#
# * * * * * * * * * * * * *
# Currently on step 620
# ##Train Cross entropy is: 0.6931467652320862
# ##Train Accuracy is: 0.5400000214576721
#
#
# ##Validation Cross entropy is: 0.6931470632553101
# ##Validation Accuracy is: 0.5099999904632568
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 630
# ##Train Cross entropy is: 0.6931471824645996
# ##Train Accuracy is: 0.5
#
#
# ##Validation Cross entropy is: 0.6931470632553101
# ##Validation Accuracy is: 0.5099999904632568
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 640
# ##Train Cross entropy is: 0.6931464672088623
# ##Train Accuracy is: 0.5400000214576721
#
#
# ##Validation Cross entropy is: 0.6931469440460205
# ##Validation Accuracy is: 0.5099999904632568
# * * * * * * * * * * * * *
#
#
# Loading model02_FIR_SPM_SINGLE_TRIAL_sub-semic020.npy data started ...
# ###  Duration Time  : 1 minutes   33 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:35:57.471682     ###
#
#
# Loading model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic020.npy data started ...
# ###  Duration Time  : 0 minutes   40 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:36:38.429387     ###
#
#
# model02_FIR_SPM_SINGLE_TRIAL_sub-semic020.npy data shape is (6051, 79, 95, 79)
# model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic020.npy data shape is (2271, 79, 95, 79)
#
#
# Concatenating is started.
# Shuffle is True
# NaN to number is True
# Y One hot transform is True
# flatten X is True
#
#
# Concatenated data shape is : (4542, 592895)
#
#
# Y shape is : (4542, 2)
#
#
# * * * * * * * * * * * * *
# Currently on step 650
# ##Train Cross entropy is: 0.6931473612785339
# ##Train Accuracy is: 0.49000000953674316
#
#
# ##Validation Cross entropy is: 0.6931480169296265
# ##Validation Accuracy is: 0.4300000071525574
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 660
# ##Train Cross entropy is: 0.6931469440460205
# ##Train Accuracy is: 0.550000011920929
#
#
# ##Validation Cross entropy is: 0.6931473612785339
# ##Validation Accuracy is: 0.4300000071525574
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 670
# ##Train Cross entropy is: 0.6931470632553101
# ##Train Accuracy is: 0.5400000214576721
#
#
# ##Validation Cross entropy is: 0.6931474208831787
# ##Validation Accuracy is: 0.4300000071525574
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 680
# ##Train Cross entropy is: 0.6931473016738892
# ##Train Accuracy is: 0.4699999988079071
#
#
# ##Validation Cross entropy is: 0.6931473612785339
# ##Validation Accuracy is: 0.4300000071525574
# * * * * * * * * * * * * *
#
#
# Loading model02_FIR_SPM_SINGLE_TRIAL_sub-semic021.npy data started ...
# ###  Duration Time  : 1 minutes   33 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:38:40.402052     ###
#
#
# Loading model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic021.npy data started ...
# ###  Duration Time  : 0 minutes   40 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:39:21.327459     ###
#
#
# model02_FIR_SPM_SINGLE_TRIAL_sub-semic021.npy data shape is (6051, 79, 95, 79)
# model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic021.npy data shape is (2271, 79, 95, 79)
#
#
# Concatenating is started.
# Shuffle is True
# NaN to number is True
# Y One hot transform is True
# flatten X is True
#
#
# Concatenated data shape is : (4542, 592895)
#
#
# Y shape is : (4542, 2)
#
#
# * * * * * * * * * * * * *
# Currently on step 690
# ##Train Cross entropy is: 0.6931469440460205
# ##Train Accuracy is: 0.5799999833106995
#
#
# ##Validation Cross entropy is: 0.6931471228599548
# ##Validation Accuracy is: 0.5199999809265137
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 700
# ##Train Cross entropy is: 0.6931473612785339
# ##Train Accuracy is: 0.47999998927116394
#
#
# ##Validation Cross entropy is: 0.6931469440460205
# ##Validation Accuracy is: 0.5199999809265137
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 710
# ##Train Cross entropy is: 0.6931474208831787
# ##Train Accuracy is: 0.47999998927116394
#
#
# ##Validation Cross entropy is: 0.6931469440460205
# ##Validation Accuracy is: 0.5199999809265137
# * * * * * * * * * * * * *
# Loading model02_FIR_SPM_SINGLE_TRIAL_sub-semic022.npy data started ...
# ###  Duration Time  : 1 minutes   34 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:41:23.587394     ###
#
#
# Loading model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic022.npy data started ...
# ###  Duration Time  : 0 minutes   40 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:42:04.431543     ###
#
#
# model02_FIR_SPM_SINGLE_TRIAL_sub-semic022.npy data shape is (6051, 79, 95, 79)
# model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic022.npy data shape is (2271, 79, 95, 79)
#
#
# Concatenating is started.
# Shuffle is True
# NaN to number is True
# Y One hot transform is True
# flatten X is True
#
#
# Concatenated data shape is : (4542, 592895)
#
#
# Y shape is : (4542, 2)
#
#
# * * * * * * * * * * * * *
# Currently on step 720
# ##Train Cross entropy is: 0.6931458115577698
# ##Train Accuracy is: 0.5899999737739563
#
#
# ##Validation Cross entropy is: 0.6931468844413757
# ##Validation Accuracy is: 0.5199999809265137
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 730
# ##Train Cross entropy is: 0.6931459903717041
# ##Train Accuracy is: 0.5400000214576721
#
#
# ##Validation Cross entropy is: 0.6931465864181519
# ##Validation Accuracy is: 0.5199999809265137
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 740
# ##Train Cross entropy is: 0.6931455135345459
# ##Train Accuracy is: 0.550000011920929
#
#
# ##Validation Cross entropy is: 0.6931464672088623
# ##Validation Accuracy is: 0.5199999809265137
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 750
# ##Train Cross entropy is: 0.6931468844413757
# ##Train Accuracy is: 0.5099999904632568
#
#
# ##Validation Cross entropy is: 0.6931465864181519
# ##Validation Accuracy is: 0.5199999809265137
# * * * * * * * * * * * * *
#
#
# Loading model02_FIR_SPM_SINGLE_TRIAL_sub-semic023.npy data started ...
# ###  Duration Time  : 1 minutes   34 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:44:06.681901     ###
#
#
# Loading model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic023.npy data started ...
# ###  Duration Time  : 0 minutes   40 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:44:47.621798     ###
#
#
# model02_FIR_SPM_SINGLE_TRIAL_sub-semic023.npy data shape is (6051, 79, 95, 79)
# model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic023.npy data shape is (2271, 79, 95, 79)
#
#
# Concatenating is started.
# Shuffle is True
# NaN to number is True
# Y One hot transform is True
# flatten X is True
#
#
# Concatenated data shape is : (4542, 592895)
#
#
# Y shape is : (4542, 2)
#
#
# * * * * * * * * * * * * *
# Currently on step 760
# ##Train Cross entropy is: 0.6931489706039429
# ##Train Accuracy is: 0.41999998688697815
#
#
# ##Validation Cross entropy is: 0.6931481957435608
# ##Validation Accuracy is: 0.44999998807907104
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 770
# ##Train Cross entropy is: 0.6931465864181519
# ##Train Accuracy is: 0.5899999737739563
#
#
# ##Validation Cross entropy is: 0.6931474804878235
# ##Validation Accuracy is: 0.44999998807907104
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 780
# ##Train Cross entropy is: 0.6931471228599548
# ##Train Accuracy is: 0.49000000953674316
#
#
# ##Validation Cross entropy is: 0.6931474804878235
# ##Validation Accuracy is: 0.44999998807907104
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 790
# ##Train Cross entropy is: 0.6931471824645996
# ##Train Accuracy is: 0.5
#
#
# ##Validation Cross entropy is: 0.6931478381156921
# ##Validation Accuracy is: 0.44999998807907104
# * * * * * * * * * * * * *
#
#
# Loading model02_FIR_SPM_SINGLE_TRIAL_sub-semic024.npy data started ...
# ###  Duration Time  : 1 minutes   34 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:46:50.588809     ###
#
#
# Loading model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic024.npy data started ...
# ###  Duration Time  : 0 minutes   40 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:47:31.449307     ###
#
#
# model02_FIR_SPM_SINGLE_TRIAL_sub-semic024.npy data shape is (6051, 79, 95, 79)
# model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic024.npy data shape is (2271, 79, 95, 79)
#
#
# Concatenating is started.
# Shuffle is True
# NaN to number is True
# Y One hot transform is True
# flatten X is True
#
#
# Concatenated data shape is : (4542, 592895)
#
#
# Y shape is : (4542, 2)
#
#
# * * * * * * * * * * * * *
# Currently on step 800
# ##Train Cross entropy is: 0.6931489706039429
# ##Train Accuracy is: 0.4099999964237213
#
#
# ##Validation Cross entropy is: 0.6931474804878235
# ##Validation Accuracy is: 0.47999998927116394
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 810
# ##Train Cross entropy is: 0.6931474804878235
# ##Train Accuracy is: 0.47999998927116394
#
#
# ##Validation Cross entropy is: 0.6931474804878235
# ##Validation Accuracy is: 0.47999998927116394
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 820
# ##Train Cross entropy is: 0.6931474208831787
# ##Train Accuracy is: 0.49000000953674316
#
#
# ##Validation Cross entropy is: 0.693147599697113
# ##Validation Accuracy is: 0.47999998927116394
# * * * * * * * * * * * * *
#
#
# Loading model02_FIR_SPM_SINGLE_TRIAL_sub-semic025.npy data started ...
# ###  Duration Time  : 1 minutes   34 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:49:35.228688     ###
#
#
# Loading model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic025.npy data started ...
# ###  Duration Time  : 0 minutes   41 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:50:16.546121     ###
#
#
# model02_FIR_SPM_SINGLE_TRIAL_sub-semic025.npy data shape is (6051, 79, 95, 79)
# model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic025.npy data shape is (2271, 79, 95, 79)
#
#
# Concatenating is started.
# Shuffle is True
# NaN to number is True
# Y One hot transform is True
# flatten X is True
#
#
# Concatenated data shape is : (4542, 592895)
#
#
# Y shape is : (4542, 2)
#
#
# * * * * * * * * * * * * *
# Currently on step 830
# ##Train Cross entropy is: 0.6931443214416504
# ##Train Accuracy is: 0.6100000143051147
#
#
# ##Validation Cross entropy is: 0.6931459903717041
# ##Validation Accuracy is: 0.5400000214576721
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 840
# ##Train Cross entropy is: 0.6931504011154175
# ##Train Accuracy is: 0.4099999964237213
#
#
# ##Validation Cross entropy is: 0.6931456923484802
# ##Validation Accuracy is: 0.5400000214576721
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 850
# ##Train Cross entropy is: 0.6931458115577698
# ##Train Accuracy is: 0.5400000214576721
#
#
# ##Validation Cross entropy is: 0.6931456923484802
# ##Validation Accuracy is: 0.5400000214576721
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 860
# ##Train Cross entropy is: 0.6931484937667847
# ##Train Accuracy is: 0.46000000834465027
#
#
# ##Validation Cross entropy is: 0.6931458115577698
# ##Validation Accuracy is: 0.5400000214576721
# * * * * * * * * * * * * *
#
#
# Loading model02_FIR_SPM_SINGLE_TRIAL_sub-semic026.npy data started ...
# ###  Duration Time  : 1 minutes   34 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:53:05.994672     ###
#
#
# Loading model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic026.npy data started ...
# ###  Duration Time  : 0 minutes   41 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:53:47.420142     ###
#
#
# model02_FIR_SPM_SINGLE_TRIAL_sub-semic026.npy data shape is (6051, 79, 95, 79)
# model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic026.npy data shape is (2271, 79, 95, 79)
#
#
# Concatenating is started.
# Shuffle is True
# NaN to number is True
# Y One hot transform is True
# flatten X is True
#
#
# Concatenated data shape is : (4542, 592895)
#
#
# Y shape is : (4542, 2)
#
#
# * * * * * * * * * * * * *
# Currently on step 870
# ##Train Cross entropy is: 0.6931456923484802
# ##Train Accuracy is: 0.5799999833106995
#
#
# ##Validation Cross entropy is: 0.693146824836731
# ##Validation Accuracy is: 0.5199999809265137
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 880
# ##Train Cross entropy is: 0.6931484341621399
# ##Train Accuracy is: 0.4399999976158142
#
#
# ##Validation Cross entropy is: 0.6931467652320862
# ##Validation Accuracy is: 0.5199999809265137
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 890
# ##Train Cross entropy is: 0.6931483745574951
# ##Train Accuracy is: 0.44999998807907104
#
#
# ##Validation Cross entropy is: 0.6931467652320862
# ##Validation Accuracy is: 0.5199999809265137
# * * * * * * * * * * * * *
# Loading model02_FIR_SPM_SINGLE_TRIAL_sub-semic027.npy data started ...
# ###  Duration Time  : 1 minutes   35 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:55:51.670301     ###
#
#
# Loading model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic027.npy data started ...
# ###  Duration Time  : 0 minutes   41 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:56:33.142349     ###
#
#
# model02_FIR_SPM_SINGLE_TRIAL_sub-semic027.npy data shape is (6051, 79, 95, 79)
# model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic027.npy data shape is (2271, 79, 95, 79)
#
#
# Concatenating is started.
# Shuffle is True
# NaN to number is True
# Y One hot transform is True
# flatten X is True
#
#
# Concatenated data shape is : (4542, 592895)
#
#
# Y shape is : (4542, 2)
#
#
# * * * * * * * * * * * * *
# Currently on step 900
# ##Train Cross entropy is: 0.6931458115577698
# ##Train Accuracy is: 0.5600000023841858
#
#
# ##Validation Cross entropy is: 0.6931469440460205
# ##Validation Accuracy is: 0.5099999904632568
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 910
# ##Train Cross entropy is: 0.6931465268135071
# ##Train Accuracy is: 0.5299999713897705
#
#
# ##Validation Cross entropy is: 0.6931469440460205
# ##Validation Accuracy is: 0.5099999904632568
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 920
# ##Train Cross entropy is: 0.6931485533714294
# ##Train Accuracy is: 0.46000000834465027
#
#
# ##Validation Cross entropy is: 0.6931468844413757
# ##Validation Accuracy is: 0.5099999904632568
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 930
# ##Train Cross entropy is: 0.6931487321853638
# ##Train Accuracy is: 0.46000000834465027
#
#
# ##Validation Cross entropy is: 0.693146824836731
# ##Validation Accuracy is: 0.5099999904632568
# * * * * * * * * * * * * *
#
#
# Loading model02_FIR_SPM_SINGLE_TRIAL_sub-semic028.npy data started ...
# ###  Duration Time  : 1 minutes   35 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:58:37.930155     ###
#
#
# Loading model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic028.npy data started ...
# ###  Duration Time  : 0 minutes   41 seconds      ###
# ###  Excecuted Time : 2019-04-25 12:59:19.398907     ###
#
#
# model02_FIR_SPM_SINGLE_TRIAL_sub-semic028.npy data shape is (6051, 79, 95, 79)
# model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic028.npy data shape is (2271, 79, 95, 79)
#
#
# Concatenating is started.
# Shuffle is True
# NaN to number is True
# Y One hot transform is True
# flatten X is True
#
#
# Concatenated data shape is : (4542, 592895)
#
#
# Y shape is : (4542, 2)
#
#
# * * * * * * * * * * * * *
# Currently on step 940
# ##Train Cross entropy is: 0.6931483745574951
# ##Train Accuracy is: 0.4099999964237213
#
#
# ##Validation Cross entropy is: 0.6931474208831787
# ##Validation Accuracy is: 0.4699999988079071
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 950
# ##Train Cross entropy is: 0.6931471824645996
# ##Train Accuracy is: 0.5
#
#
# ##Validation Cross entropy is: 0.6931470632553101
# ##Validation Accuracy is: 0.5299999713897705
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 960
# ##Train Cross entropy is: 0.6931480169296265
# ##Train Accuracy is: 0.4099999964237213
#
#
# ##Validation Cross entropy is: 0.6931469440460205
# ##Validation Accuracy is: 0.5299999713897705
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 970
# ##Train Cross entropy is: 0.6931470632553101
# ##Train Accuracy is: 0.5099999904632568
#
#
# ##Validation Cross entropy is: 0.6931470632553101
# ##Validation Accuracy is: 0.5299999713897705
# * * * * * * * * * * * * *
#
#
# Loading model02_FIR_SPM_SINGLE_TRIAL_sub-semic029.npy data started ...
# ###  Duration Time  : 1 minutes   36 seconds      ###
# ###  Excecuted Time : 2019-04-25 13:01:25.455949     ###
#
#
# Loading model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic029.npy data started ...
# ###  Duration Time  : 0 minutes   41 seconds      ###
# ###  Excecuted Time : 2019-04-25 13:02:06.861548     ###
#
#
# model02_FIR_SPM_SINGLE_TRIAL_sub-semic029.npy data shape is (6051, 79, 95, 79)
# model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic029.npy data shape is (2271, 79, 95, 79)
#
#
# Concatenating is started.
# Shuffle is True
# NaN to number is True
# Y One hot transform is True
# flatten X is True
#
#
# Concatenated data shape is : (4542, 592895)
#
#
# Y shape is : (4542, 2)
#
#
# * * * * * * * * * * * * *
# Currently on step 980
# ##Train Cross entropy is: 0.6931470632553101
# ##Train Accuracy is: 0.550000011920929
#
#
# ##Validation Cross entropy is: 0.6931469440460205
# ##Validation Accuracy is: 0.5600000023841858
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 990
# ##Train Cross entropy is: 0.6931470632553101
# ##Train Accuracy is: 0.5400000214576721
#
#
# ##Validation Cross entropy is: 0.6931474208831787
# ##Validation Accuracy is: 0.4399999976158142
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 1000
# ##Train Cross entropy is: 0.6931490898132324
# ##Train Accuracy is: 0.41999998688697815
#
#
# ##Validation Cross entropy is: 0.693148672580719
# ##Validation Accuracy is: 0.4399999976158142
# * * * * * * * * * * * * *
#
#
# Loading model02_FIR_SPM_SINGLE_TRIAL_sub-semic030.npy data started ...
# ###  Duration Time  : 1 minutes   36 seconds      ###
# ###  Excecuted Time : 2019-04-25 13:04:13.053268     ###
#
#
# Loading model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic030.npy data started ...
# ###  Duration Time  : 0 minutes   41 seconds      ###
# ###  Excecuted Time : 2019-04-25 13:04:54.468437     ###
#
#
# model02_FIR_SPM_SINGLE_TRIAL_sub-semic030.npy data shape is (6051, 79, 95, 79)
# model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic030.npy data shape is (2271, 79, 95, 79)
#
#
# Concatenating is started.
# Shuffle is True
# NaN to number is True
# Y One hot transform is True
# flatten X is True
#
#
# Concatenated data shape is : (4542, 592895)
#
#
# Y shape is : (4542, 2)
#
#
# * * * * * * * * * * * * *
# Currently on step 1010
# ##Train Cross entropy is: 0.6931476593017578
# ##Train Accuracy is: 0.47999998927116394
#
#
# ##Validation Cross entropy is: 0.6931465268135071
# ##Validation Accuracy is: 0.5299999713897705
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 1020
# ##Train Cross entropy is: 0.6931456923484802
# ##Train Accuracy is: 0.5799999833106995
#
#
# ##Validation Cross entropy is: 0.6931465864181519
# ##Validation Accuracy is: 0.5299999713897705
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 1030
# ##Train Cross entropy is: 0.6931476593017578
# ##Train Accuracy is: 0.47999998927116394
#
#
# ##Validation Cross entropy is: 0.6931463479995728
# ##Validation Accuracy is: 0.5299999713897705
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 1040
# ##Train Cross entropy is: 0.6931473016738892
# ##Train Accuracy is: 0.5
#
#
# ##Validation Cross entropy is: 0.6931465864181519
# ##Validation Accuracy is: 0.5299999713897705
# * * * * * * * * * * * * *
#
#
# Loading model02_FIR_SPM_SINGLE_TRIAL_sub-semic031.npy data started ...
# ###  Duration Time  : 1 minutes   36 seconds      ###
# ###  Excecuted Time : 2019-04-25 13:07:00.991869     ###
#
#
# Loading model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic031.npy data started ...
# ###  Duration Time  : 0 minutes   41 seconds      ###
# ###  Excecuted Time : 2019-04-25 13:07:42.712093     ###
#
#
# model02_FIR_SPM_SINGLE_TRIAL_sub-semic031.npy data shape is (6051, 79, 95, 79)
# model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic031.npy data shape is (2271, 79, 95, 79)
#
#
# Concatenating is started.
# Shuffle is True
# NaN to number is True
# Y One hot transform is True
# flatten X is True
#
#
# Concatenated data shape is : (4542, 592895)
#
#
# Y shape is : (4542, 2)
#
#
# * * * * * * * * * * * * *
# Currently on step 1050
# ##Train Cross entropy is: 0.6931476593017578
# ##Train Accuracy is: 0.47999998927116394
#
#
# ##Validation Cross entropy is: 0.693148672580719
# ##Validation Accuracy is: 0.4399999976158142
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 1060
# ##Train Cross entropy is: 0.6931504011154175
# ##Train Accuracy is: 0.38999998569488525
#
#
# ##Validation Cross entropy is: 0.6931488513946533
# ##Validation Accuracy is: 0.4399999976158142
# * * * * * * * * * * * * *
#
#
# * * * * * * * * * * * * *
# Currently on step 1070
# ##Train Cross entropy is: 0.6931462287902832
# ##Train Accuracy is: 0.5400000214576721
#
#
# ##Validation Cross entropy is: 0.6931487321853638
# ##Validation Accuracy is: 0.4399999976158142
# * * * * * * * * * * * * *
# Loading model02_FIR_SPM_SINGLE_TRIAL_sub-semic032.npy data started ...
# ###  Duration Time  : 1 minutes   37 seconds      ###
# ###  Excecuted Time : 2019-04-25 13:09:50.283743     ###
#
#
# Loading model02_Overall_FIR_SPM_SINGLE_TRIAL_sub-semic032.npy data started ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-1a1fab1b834e> in <module>
#      29             del Y
#      30
# ---> 31             X, Y = load_data(subject_num, shuffle=True, nan_to_num=True, one_hot_y=True, flatten_X=True)
#      32
#      33             if subject_num<57:
#
# <ipython-input-7-6120cce5abcb> in load_data(subjec_num, shuffle, nan_to_num, one_hot_y, flatten_X)
#      23     start = timeit.default_timer()
#      24
# ---> 25     X_control = np.load(full_path_list[1,subjec_num-1])
#      26
#      27     if nan_to_num:
#
# ~/anaconda3/envs/tf3/lib/python3.6/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     419             else:
#     420                 return format.read_array(fid, allow_pickle=allow_pickle,
# --> 421                                          pickle_kwargs=pickle_kwargs)
#     422         else:
#     423             # Try a pickle
#
# ~/anaconda3/envs/tf3/lib/python3.6/site-packages/numpy/lib/format.py in read_array(fp, allow_pickle, pickle_kwargs)
#     659         if isfileobj(fp):
#     660             # We can use the fast fromfile() function.
# --> 661             array = numpy.fromfile(fp, dtype=dtype, count=count)
#     662         else:
#     663             # This is not a real file. We have to read it the
#
# KeyboardInterrupt:

# %% [markdown]
# # Visualize result

# %%
result_list = pd.DataFrame({"train_acc_list":train_acc_list,"validation_acc_list":validation_acc_list,
                            "train_entrop_list":train_entrop_list,"validation_entrop_list":validataion_entrop_list,
                            "step":step_list})
result_list.head()
# Out:
#    train_acc_list  validation_acc_list  train_entrop_list  \
# 0            0.47                 0.50           0.707430
# 1            0.55                 0.51           0.692741
# 2            0.64                 0.55           0.647031
# 3            0.72                 0.63           0.612834
# 4            0.71                 0.67           0.622026
#
#    validation_entrop_list  step
# 0                0.693222     0
# 1                0.691638     1
# 2                0.690067     2
# 3                0.688495     3
# 4                0.687037     4

# %%
test_result_list = pd.DataFrame({"test_acc_list":test_acc_list, "test_entrop_list":test_entrop_list,
                            "test_step":test_step_list})
test_result_list.head()
# Out:
#    test_acc_list  test_entrop_list  test_step
# 0           0.91          0.661352         96
# 1           0.91          0.657910         97
# 2           0.91          0.658062         98
# 3           0.91          0.660671         99

# %%
plt.figure(figsize=(15,8))

plt.subplot(211)
plt.xlabel("Step")
plt.ylabel("Accuracy")
sns.lineplot(x = result_list["step"], y= result_list["train_acc_list"])
sns.lineplot(x = result_list["step"], y= result_list["validation_acc_list"])


plt.subplot(212)
plt.xlabel("Step")
plt.ylabel("Cross entropy")
sns.lineplot(x = result_list["step"], y = result_list["train_entrop_list"])
sns.lineplot(x = result_list["step"], y= result_list["validation_entrop_list"])

# %%
plt.figure(figsize=(15,8))

plt.subplot(211)
plt.xlabel("Step")
plt.ylabel("Accuracy")
sns.lineplot(x = test_result_list["test_step"], y= test_result_list["test_acc_list"])

plt.subplot(212)
plt.xlabel("Step")
plt.ylabel("Cross entropy")
sns.lineplot(x = test_result_list["test_step"], y= test_result_list["test_entrop_list"])

# %%
train_acc_list = []
train_entrop_list = []

test_acc_list = []
test_entrop_list = []

validation_acc_list = []
validataion_entrop_list = []

step_list = []

lowest_loss = None

X = []
Y = []

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    saver = tf.train.Saver()
    
    subject_num = 1
    start = timeit.default_timer()

    for i in range(step_size):
        
        #Loading training and validation data sets
        if i%36 == 0 and i < step_size-44:
            del X
            del Y
            
            
            X, Y = load_data(subject_num, shuffle=True, nan_to_num=True, one_hot_y=True, flatten_X=True)
            
            if subject_num<57:
                subject_num +=1   
            
            elif subject_num>=57:
                subject_num =1    

        #Load test data sets
        elif i == step_size-44:    
            validate_subjec_num = 58
            X, Y = load_data(validate_subjec_num, shuffle=True, nan_to_num=True, one_hot_y=True, flatten_X=True)

        matches = tf.equal(tf.argmax(y_pred,1),tf.argmax(y_true,1))
        acc = tf.reduce_mean(tf.cast(matches,tf.float32))
        
        #training model
        if i < step_size-44:
            j = i%44
            _, train_entropy, train_accuracy = sess.run([train, cross_entropy, acc], 
                                                        feed_dict={x: X[j*100:j*100+100], 
                                                                   y_true: Y[j*100:j*100+100], 
                                                                   hold_prob: 0.5, is_train:True})

            validation_entropy, validation_accuracy= sess.run([cross_entropy, acc],
                                                  feed_dict={x: X[4400:4500], 
                                                             y_true: Y[4400:4500], 
                                                             hold_prob:1.0, is_train:False})
            if i%10 == 0:
                print("* * * * * * * * * * * * *")
                print('Currently on step {}'.format(i))
                print('##Train Cross entropy is: {}'.format(train_entropy))
                print('##Train Accuracy is: {}'.format(train_accuracy))
                print('\n')
                print('##Validation Cross entropy is: {}'.format(validation_entropy))
                print('##Validation Accuracy is: {}'.format(validation_accuracy))

                print("* * * * * * * * * * * * *")
                print('\n')
                
            train_acc_list.append(train_accuracy)
            train_entrop_list.append(train_entropy)
            
            validation_acc_list.append(validation_accuracy)
            validataion_entrop_list.append(validation_entropy)
            
            step_list.append(i)

        #testing model
        elif i > step_size-44:
            j = i%44
            test_entropy, test_accuracy= sess.run([cross_entropy, acc],
                                                  feed_dict={x:X[j*100:j*100+100], 
                                                             y_true:Y[j*100:j*100+100], 
                                                             hold_prob:1.0, is_train:False})

            test_acc_list.append(test_accuracy)
            test_entrop_list.append(test_entropy)
            
            step_list.append(i)
            
            if i%1 == 0:
                print("* * * * * * * * * * * * *")
                print('Currently on step {}'.format(i))
                print('##Test Cross entropy is: {}'.format(test_entropy))
                print('##Test Accuracy is: {}'.format(test_accuracy))

                print("* * * * * * * * * * * * *")
                print('\n')
                
'''
        if lowest_loss == None or lowest_loss > validation_entropy:
            lowest_loss = validation_entropy
            saver.save(sess, "./model/MPC_dnn_basic_SEMIC_binary_classification_ver4.ckpt")
'''

train_acc_list = np.array(train_acc_list)
train_entrop_list = np.array(train_entrop_list)

test_entrop_list = np.array(test_entrop_list)
test_acc_list = np.array(test_acc_list)

validation_acc_list = np.array(validation_acc_list)
validataion_entrop_list = np.array(validataion_entrop_list)

step_list = np.array(step_list)

stop = timeit.default_timer()
check_time = stop-start
now = datetime.datetime.now()

print("!!!!Finished!!!!")
print("###  Duration Time  : {} minutes   {} seconds      ###".format(int(check_time)//60, int(check_time)%60))
print("###  Excecuted Time : {}     ###".format(now))
